# %%
# importing dependencies and stuff
import queue
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf
import pyvirtualcam as vcam
import pyttsx3
import pyaudio
import wave
from threading import Thread
import sounddevice as sd
import soundfile as sf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from PIL import ImageFont, ImageDraw, Image
from multiprocessing import Process

# %%
# Creating mediapipe init variables

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
# Detecting mediapipe values per frame

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
# Drawing mediapipe values per frame

def draw_landmarks(image, results):
    # mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
    #                          mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
    #                          mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

# %%
# # Program to capture video, detect and render landmarks and output video //MAINLY USED FOR DEBUGGING STUFF
# cap = cv2.VideoCapture(0)
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():
#         ret, frame = cap.read()

#         image, results = mediapipe_detection(frame, holistic)
#         print(results)

#         draw_landmarks(image, results)

#         image = cv2.flip(image, 1)
#         cv2.imshow('Feed', image)
        
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

# %%
# Extract every landmark value and concatenating it into one array
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
# creating a folder to store action data for training, reading actions from list and initialization stuff

DATA_PATH = os.path.join('MP_Data') 

actions = np.array(['my', 'name', 'hello', 'yes', 'IDLE'])
# actions1 = np.array(['my', 'name', 'hello', 'yes', 'NULL'])

no_sequences = 120 # number of videos to record

sequence_length = 30 #length of each video

# %%
# Creating the directory structure

for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
# Creating an audio file for each action

engine = pyttsx3.init()
engine.setProperty('rate', 125)

for action in actions:
    engine.save_to_file(action, f"Audio/{action}.wav")
    engine.runAndWait()
    engine.setProperty('voice', engine.getProperty('voices')[1].id)

# %%
# data collection Function for each action if action has not been collected yet

cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        if os.path.isfile(os.path.join(DATA_PATH, action, "0", "0.npy")):
            continue
        for sequence in range(no_sequences):
            for frame_num in range(sequence_length):

                ret, frame = cap.read()

                image, results = mediapipe_detection(frame, holistic)

                draw_landmarks(image, results)
                
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)
                
                if cv2.waitKey(10) & 0xFF == ord('q'): #press q to quit after finished training action safely
                    break
        if cv2.waitKey(0) & 0xFF == ord('n'): #press n to go to next action after finished training current one
            pass
        if cv2.waitKey(0) & 0xFF == ord('q'): #press q to quit after finished training action safely
            break
    
    cap.release()
    cv2.destroyAllWindows()

# %%
# Cell to create training data for the model

label_map = {label:num for num, label in enumerate(actions)}
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

x = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.05)
len(X_train)
# Out:
# 570

# %%
# Creating the model's structure and stuff

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# C:\Users\ryanl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Loading saved weights if u want

model.load_weights('joyV2.keras')
# Out:
# C:\Users\ryanl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 32 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Displays model stuff

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 30, 64)              │         442,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 30, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │             165 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,790,225 (6.83 MB)
#  Trainable params: 596,741 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,484 (4.55 MB)

# %%
# IMPORTANT: THIS ACTUALLY TRAINS THE MODEL

model.fit(X_train, y_train, epochs=400, callbacks=[tb_callback], batch_size=10)
# Out:
# Epoch 1/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - categorical_accuracy: 0.2011 - loss: 1.9957
# Epoch 2/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - categorical_accuracy: 0.2023 - loss: 1.5701
# Epoch 3/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - categorical_accuracy: 0.4049 - loss: 1.4877
# Epoch 4/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - categorical_accuracy: 0.3297 - loss: 1.5059
# Epoch 5/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - categorical_accuracy: 0.2041 - loss: 1.5826
# Epoch 6/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - categorical_accuracy: 0.3727 - loss: 1.3031
# Epoch 7/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - categorical_accuracy: 0.2034 - loss: 1.5733
# Epoch 8/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - categorical_accuracy: 0.2079 - loss: 1.6176
# Epoch 9/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - categorical_accuracy: 0.3042 - loss: 1.4584
# Epoch 10/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2113 - loss: 1.6131
# Epoch 11/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2216 - loss: 1.6110
# Epoch 12/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2361 - loss: 1.6089
# Epoch 13/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2168 - loss: 1.6092
# Epoch 14/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2172 - loss: 1.6087
# Epoch 15/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2081 - loss: 1.6082
# Epoch 16/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2019 - loss: 1.6094
# Epoch 17/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1848 - loss: 1.6110
# Epoch 18/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1991 - loss: 1.6109
# Epoch 19/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2190 - loss: 1.6096
# Epoch 20/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1969 - loss: 1.6103
# Epoch 21/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2122 - loss: 1.6090
# Epoch 22/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2116 - loss: 1.6103
# Epoch 23/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2280 - loss: 1.6083
# Epoch 24/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2365 - loss: 1.6068
# Epoch 25/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2975 - loss: 1.5839
# Epoch 26/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2044 - loss: 1.6105
# Epoch 27/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1784 - loss: 1.6111
# Epoch 28/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1785 - loss: 1.6104
# Epoch 29/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.1895 - loss: 1.6106
# Epoch 30/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1636 - loss: 1.6106
# Epoch 31/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2235 - loss: 1.6087
# Epoch 32/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2133 - loss: 1.6095
# Epoch 33/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2110 - loss: 1.6096
# Epoch 34/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2033 - loss: 1.6098
# Epoch 35/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.1774 - loss: 1.6104
# Epoch 36/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2229 - loss: 1.6087
# Epoch 37/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2040 - loss: 1.6106
# Epoch 38/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1939 - loss: 1.6101
# Epoch 39/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1763 - loss: 1.6096
# Epoch 40/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2202 - loss: 1.6091
# Epoch 41/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2284 - loss: 1.6091
# Epoch 42/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.1653 - loss: 1.6099
# Epoch 43/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2207 - loss: 1.6090
# Epoch 44/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.2075 - loss: 1.6094
# Epoch 45/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2082 - loss: 1.6096
# Epoch 46/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2259 - loss: 1.6090
# Epoch 47/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2297 - loss: 1.6086
# Epoch 48/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - categorical_accuracy: 0.1985 - loss: 1.6092
# Epoch 49/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2279 - loss: 1.6096
# Epoch 50/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2261 - loss: 1.6089
# Epoch 51/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2170 - loss: 1.6095
# Epoch 52/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2199 - loss: 1.6100
# Epoch 53/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1923 - loss: 1.6095
# Epoch 54/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1782 - loss: 1.6103
# Epoch 55/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2143 - loss: 1.6092
# Epoch 56/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1942 - loss: 1.6112
# Epoch 57/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1920 - loss: 1.6101
# Epoch 58/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2247 - loss: 1.6090
# Epoch 59/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2048 - loss: 1.6098
# Epoch 60/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2055 - loss: 1.6096
# Epoch 61/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1955 - loss: 1.6099
# Epoch 62/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2277 - loss: 1.6085
# Epoch 63/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2162 - loss: 1.6095
# Epoch 64/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2254 - loss: 1.6080
# Epoch 65/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2325 - loss: 1.8825
# Epoch 66/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1829 - loss: 1.6095
# Epoch 67/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.2294 - loss: 1.6089
# Epoch 68/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - categorical_accuracy: 0.1698 - loss: 1.6102
# Epoch 69/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2182 - loss: 1.6093
# Epoch 70/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1791 - loss: 1.6109
# Epoch 71/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2174 - loss: 1.6089
# Epoch 72/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2417 - loss: 1.6077
# Epoch 73/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1968 - loss: 1.6107
# Epoch 74/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2030 - loss: 1.6094
# Epoch 75/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1687 - loss: 1.6097
# Epoch 76/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.1688 - loss: 1.6101
# Epoch 77/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.1829 - loss: 1.6101
# Epoch 78/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1998 - loss: 1.6100
# Epoch 79/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2180 - loss: 1.6094
# Epoch 80/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1936 - loss: 1.6094
# Epoch 81/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2038 - loss: 1.6095
# Epoch 82/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1746 - loss: 1.6100
# Epoch 83/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1972 - loss: 1.6094
# Epoch 84/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2112 - loss: 1.6092
# Epoch 85/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1909 - loss: 1.6107
# Epoch 86/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.2108 - loss: 1.6096
# Epoch 87/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2317 - loss: 1.6085
# Epoch 88/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2258 - loss: 1.6098
# Epoch 89/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2145 - loss: 1.6093
# Epoch 90/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2119 - loss: 1.6094
# Epoch 91/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1867 - loss: 1.6090
# Epoch 92/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2070 - loss: 1.6097
# Epoch 93/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1835 - loss: 1.6099
# Epoch 94/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2173 - loss: 1.6091
# Epoch 95/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1577 - loss: 1.6111
# Epoch 96/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2045 - loss: 1.6097
# Epoch 97/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1980 - loss: 1.6098
# Epoch 98/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2008 - loss: 1.6098
# Epoch 99/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2217 - loss: 1.6091
# Epoch 100/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.1924 - loss: 1.6093
# Epoch 101/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.1964 - loss: 1.6094
# Epoch 102/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2271 - loss: 1.6094
# Epoch 103/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2132 - loss: 1.6094
# Epoch 104/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.2000 - loss: 1.6103
# Epoch 105/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2185 - loss: 1.6087
# Epoch 106/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2056 - loss: 1.6090
# Epoch 107/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2312 - loss: 1.6089
# Epoch 108/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2298 - loss: 1.6087
# Epoch 109/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2303 - loss: 1.6091
# Epoch 110/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2175 - loss: 1.6088
# Epoch 111/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2425 - loss: 1.6091
# Epoch 112/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2161 - loss: 1.6096
# Epoch 113/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2205 - loss: 1.6091
# Epoch 114/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2295 - loss: 1.6091
# Epoch 115/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1963 - loss: 1.6094
# Epoch 116/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1752 - loss: 1.6096
# Epoch 117/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2070 - loss: 1.6097
# Epoch 118/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2240 - loss: 1.6089
# Epoch 119/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1708 - loss: 1.6106
# Epoch 120/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1632 - loss: 1.6108
# Epoch 121/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1578 - loss: 1.6105
# Epoch 122/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2028 - loss: 1.6100
# Epoch 123/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2151 - loss: 1.6095
# Epoch 124/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1758 - loss: 1.6106
# Epoch 125/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1877 - loss: 1.6102
# Epoch 126/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.1822 - loss: 1.6110
# Epoch 127/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2059 - loss: 1.6094
# Epoch 128/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2067 - loss: 1.6094
# Epoch 129/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2069 - loss: 1.6088
# Epoch 130/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1802 - loss: 1.6107
# Epoch 131/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1922 - loss: 1.6099
# Epoch 132/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1962 - loss: 1.6098
# Epoch 133/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2044 - loss: 1.6099
# Epoch 134/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1967 - loss: 1.6100
# Epoch 135/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1892 - loss: 1.6104
# Epoch 136/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2041 - loss: 1.6097
# Epoch 137/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1831 - loss: 1.6097
# Epoch 138/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1681 - loss: 1.6109
# Epoch 139/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1986 - loss: 1.6099
# Epoch 140/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1948 - loss: 1.6100
# Epoch 141/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2000 - loss: 1.6101
# Epoch 142/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.1919 - loss: 1.6100
# Epoch 143/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2029 - loss: 1.6099
# Epoch 144/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.1900 - loss: 1.6097
# Epoch 145/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - categorical_accuracy: 0.2007 - loss: 1.6096
# Epoch 146/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1960 - loss: 1.6100
# Epoch 147/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1968 - loss: 1.6096
# Epoch 148/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1978 - loss: 1.6101
# Epoch 149/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1820 - loss: 1.6109
# Epoch 150/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2066 - loss: 1.6093
# Epoch 151/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1981 - loss: 1.6100
# Epoch 152/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2030 - loss: 1.6099
# Epoch 153/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - categorical_accuracy: 0.2188 - loss: 1.6090
# Epoch 154/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - categorical_accuracy: 0.2286 - loss: 1.6088
# Epoch 155/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2166 - loss: 1.6089
# Epoch 156/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1969 - loss: 1.6096
# Epoch 157/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1935 - loss: 1.6101
# Epoch 158/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2019 - loss: 1.6096
# Epoch 159/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1987 - loss: 1.6097
# Epoch 160/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2190 - loss: 1.6088
# Epoch 161/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2092 - loss: 1.6092
# Epoch 162/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - categorical_accuracy: 0.2329 - loss: 1.6090
# Epoch 163/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - categorical_accuracy: 0.2044 - loss: 1.6099
# Epoch 164/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - categorical_accuracy: 0.2013 - loss: 1.6101
# Epoch 165/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2138 - loss: 1.6086
# Epoch 166/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2045 - loss: 1.6098
# Epoch 167/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2107 - loss: 1.6091
# Epoch 168/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1693 - loss: 1.6097
# Epoch 169/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1950 - loss: 1.6102
# Epoch 170/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1650 - loss: 1.6100
# Epoch 171/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1742 - loss: 1.6105
# Epoch 172/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2123 - loss: 1.6087
# Epoch 173/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2061 - loss: 1.6091
# Epoch 174/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1898 - loss: 1.6102
# Epoch 175/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2072 - loss: 1.6097
# Epoch 176/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2039 - loss: 1.6099
# Epoch 177/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2140 - loss: 1.6090
# Epoch 178/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2276 - loss: 1.6093
# Epoch 179/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1936 - loss: 1.6098
# Epoch 180/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2220 - loss: 1.6095
# Epoch 181/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2240 - loss: 1.6092
# Epoch 182/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1748 - loss: 1.6109
# Epoch 183/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.2067 - loss: 1.6099
# Epoch 184/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1832 - loss: 1.6102
# Epoch 185/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1975 - loss: 1.6099
# Epoch 186/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - categorical_accuracy: 0.1893 - loss: 1.6095
# Epoch 187/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2021 - loss: 1.6103
# Epoch 188/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2150 - loss: 1.6085
# Epoch 189/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - categorical_accuracy: 0.1928 - loss: 1.6096
# Epoch 190/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1837 - loss: 1.6097
# Epoch 191/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2101 - loss: 1.6099
# Epoch 192/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1871 - loss: 1.6104
# Epoch 193/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2028 - loss: 1.6101
# Epoch 194/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.1943 - loss: 1.6096
# Epoch 195/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2158 - loss: 1.6090
# Epoch 196/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1974 - loss: 1.6099
# Epoch 197/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1634 - loss: 1.6107
# Epoch 198/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2215 - loss: 1.6087
# Epoch 199/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.1997 - loss: 1.6102
# Epoch 200/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - categorical_accuracy: 0.2061 - loss: 1.6103
# Epoch 201/400
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - categorical_accuracy: 0.2180 - loss: 1.6091
# Epoch 202/400
# 29/57 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.2180 - loss: 1.6076

# %%
# dont touch this
del model

# %%
# Checking if it can predict 2 frames
res = model.predict(X_test)

actions[np.argmax(y_train[1])]

actions[np.argmax(y_test[1])]

# %%
# Saves the model if u want

model.save("joyV2.keras")

# %%
# Checks accuracy of model

yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

multilabel_confusion_matrix(ytrue, yhat)

accuracy_score(ytrue, yhat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Checks accuracy of model
# ----> 3 yhat = model.predict(X_test)
#       4 ytrue = np.argmax(y_test, axis=1).tolist()
#       5 yhat = np.argmax(yhat, axis=1).tolist()
#
# NameError: name 'X_test' is not defined

# %%
# Function to play audio of subtitles

def AudioPlay(text):
  data, fs = sf.read(text)
  sd.play(data, fs)
  sd.wait()

# %%
# The final product

sequence = []
sentence = []
sound = []
threshold = 0.90

font = ImageFont.truetype("Minecraftia-Regular.ttf", 32)



sd.default.samplerate = 22050
sd.default.device = 10
i = 0
cap = cv2.VideoCapture(0)



# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    with vcam.Camera(width=640, height=480, fps=30) as cam:
        while cap.isOpened():
    
            # Read feed
            ret, frame = cap.read()
            i += 1
            # Make detections
            image, results = mediapipe_detection(frame, holistic)

            # Draw landmarks
            draw_landmarks(image, results)
            image = cv2.flip(image, 1)

            # Prediction logic stuff
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]


            if len(sequence) == 30 and i % 2 == 0:
                res = model.predict(np.expand_dims(sequence, axis=0), verbose = 0)[0]                
                
            # Visualisation stuff
                if res[np.argmax(res)] > threshold and actions[np.argmax(res)] != 'IDLE': 
                        if len(sentence) > 0: 
                            if actions[np.argmax(res)] != sentence[-1]:
                                sentence.append(actions[np.argmax(res)])
                                sound.append(f'Audio/{sentence[-1]}.wav')

                                
                        else:
                            sentence.append(actions[np.argmax(res)]) 
                            sound.append(f'Audio/{sentence[-1]}.wav')
                if len(sentence) > 5: 
                    sentence = sentence[-5:]

            if i % 10 == 0 and len(sound) > 0:
                Thread(target=AudioPlay, args=(sound[-1],)).start()
                sound.pop(0)
                
            if i % 60 == 0 and len(sentence) > 0:
                sentence.pop(0)

            img_pil = Image.fromarray(image)
            draw = ImageDraw.Draw(img_pil)
            draw.text((0, 400), '\t\t'.join(sentence), font=font, fill=(255, 255, 255, 0))

            image = np.array(img_pil)
            
            # Show to screen
            cv2.namedWindow('OpenCV Feed', cv2.WINDOW_NORMAL)
            cv2.imshow('OpenCV Feed', image)
    
            # Output into Vcam
            cam.send(cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_RGB2BGR) )
            cam.sleep_until_next_frame()
            
            # Break
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
# Do this if fail
cap.release()
cv2.destroyAllWindows()

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
model(np.expand_dims(sequence, axis=0))[0]
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([3.5177823e-04, 1.8362563e-08, 9.9874401e-01, 8.9288887e-04,
#        1.1181803e-05], dtype=float32)>

# %%
# !pip install tensorflow==2.10.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.10.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0)
# ERROR: No matching distribution found for tensorflow==2.10.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ryanl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
